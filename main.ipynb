# %% [markdown]
# <h1>ЛАБОРАТОРНАЯ РАБОТА НОМЕР 9</h1>

# %% [markdown]
# <h2>Задачи лабораторной работы:</h2><br>
# Считать данные из Excel-файла с результатами студентов.
# Выполнить вычисления (средние, максимальные, групповые показатели).
# Построить столбчатые диаграммы по заданным вариантам.
# Подписать оси, добавить заголовки и легенды к графикам.
# Сохранить результаты и визуализации в Jupyter Notebook.

# %% [markdown]
# <h2>Цели лабораторной работы:</h2><br>
# Освоить работу с Excel-файлами средствами Python.
# Научиться использовать библиотеку openpyxl для чтения и записи данных.
# Научиться строить столбчатые диаграммы с помощью matplotlib.
# Развить навыки обработки и визуализации табличных данных.

# %% [markdown]
# <h2>Ход работы</h2>

# %% [markdown]
# <br>
# Импорт библиотек

# %%
import openpyxl
from openpyxl import load_workbook
import matplotlib.pyplot as plt

# %% [markdown]
# Загрузка данных

# %%
wb = load_workbook(r'c:\Users\Антон\Downloads\students.xlsx')
grades = wb["Оценки"] #лист с оценками

# %% [markdown]
# Cоздание пустых массивов и их заполнение

# %%
math = []
fizika = []
info = []
for row in grades.iter_rows(min_row=2, values_only=True):
    math.append(row[1])
    fizika.append(row[2])
    info.append(row[3])

# %% [markdown]
# Создание функции, которая выщитывает средний балл по предмету и вывод результата

# %%
def calc(x):
    return (sum(x)/len(x))
avg_m = calc(math)
avg_f = calc(fizika)
avg_i = calc(info)
print(f"Cредний балл по математике = {avg_m:.2f}")
print(f"Cредний балл по физике = {avg_f:.2f}")
print(f"Cредний балл по информатике = {avg_i:.2f}")

# %% [markdown]
# Создание столбчатой диаграммы

# %%
# Текст таблиц и используемые перменные
предметы = ['Математика', 'Физика', 'Информатика']
средние = [avg_m, avg_f, avg_i]


# Столбчатая диаграмма (самый простой график)
plt.figure(figsize=(8, 5))  # размер графика
plt.bar(предметы, средние, color=['blue', 'green', 'red'])

# Настройки графика
plt.title('Средние оценки', fontsize=14)
plt.ylabel('Средний балл', fontsize=12)
plt.ylim(0, 10)  # от 0 до 10 (для 10-балльной системы)

# Добавляем значения на столбцы
for i, v in enumerate(средние):
    plt.text(i, v + 0.1, f'{v:.2f}', ha='center', fontsize=11)

# Вывод
plt.grid(axis='y', alpha=0.3, linestyle='--')
plt.show()

# %% [markdown]
# ![alt text](Figure_1.png)
